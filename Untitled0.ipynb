# %% [markdown]
# <a href="https://colab.research.google.com/github/ssuwanx/Math-workshop/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME : Suhan Chaudhary
# UNi ID : 2612598

# %%
Write a Python function that takes a list and returns a new list with distinct elements from the
first list.
Sample List : [1,2,3,3,3,3,4,5]
Unique List : [1, 2, 3, 4, 5]

# %%
def unique_list(lst):
    result = []
    for item in lst:
        if item not in result:
            result.append(item)
    return result
sample_list = [1,2,3,3,3,3,4,5]
print(unique_list(sample_list))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Write a Python function that takes a number as a parameter and checks whether the number
# is prime or not.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True
num = 7
if is_prime(num):
    print(f"{num} is a prime number")
else:
    print(f"{num} is not a prime number")
# Out:
# 7 is a prime number

# %% [markdown]
# Write a program to print twin primes less than 1000. If two consecutive odd numbers are
# both prime then they are known as twin primes.

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print("Twin primes less than 1000 are:")
for i in range(3, 1000, 2):
    if is_prime(i) and is_prime(i + 2):
        print(f"({i}, {i+2})")
# Out:
# Twin primes less than 1000 are:
# (3, 5)
# (5, 7)
# (11, 13)
# (17, 19)
# (29, 31)
# (41, 43)
# (59, 61)
# (71, 73)
# (101, 103)
# (107, 109)
# (137, 139)
# (149, 151)
# (179, 181)
# (191, 193)
# (197, 199)
# (227, 229)
# (239, 241)
# (269, 271)
# (281, 283)
# (311, 313)
# (347, 349)
# (419, 421)
# (431, 433)
# (461, 463)
# (521, 523)
# (569, 571)
# (599, 601)
# (617, 619)
# (641, 643)
# (659, 661)
# (809, 811)
# (821, 823)
# (827, 829)
# (857, 859)
# (881, 883)

# %% [markdown]
# A positive integer is called a perfect number if it is equal to the sum of all of its divisors,
# including 1 but excluding the number itself. For example, 6 = 1 + 2 + 3. Write a
# function sumOfDivisors that takes a positive integer n and returns the sum of all its divisors
# (excluding n)

# %%
def sumOfDivisors(n):
    total = 0
    for i in range(1, n):
        if n % i == 0:
            total += i
    return total
sumOfDivisors(60)
# Out:
# 108

# %% [markdown]
# The smallest perfect number is 6. Write a program that finds and prints out the next perfect number. Hint:
# You should be able your sumOfDiviors function from your solution to previous question.

# %%
def sumOfDivisors(n):
    total = 0
    for i in range(1, n):
        if n % i == 0:
            total += i
    return total
number = 7
while True:
    if sumOfDivisors(number) == number:
        print("The next perfect number is:", number)
        break
    number += 1
# Out:
# The next perfect number is: 28

# %% [markdown]
# Write the python program to find the mean median from the following list:
# Marks = [20, 30, 35, 55, 70, 80, 90] Do not use the library function if there is one.

# %%
Marks = [20, 30, 35, 55, 70, 80, 90]

total = 0
for mark in Marks:
    total += mark
mean = total / len(Marks)

sorted_marks = sorted(Marks)
n = len(sorted_marks)

if n % 2 == 1:
    median = sorted_marks[n // 2]
else:
    median = (sorted_marks[(n//2) - 1] + sorted_marks[n//2]) / 2

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 54.285714285714285
# Median: 55

# %% [markdown]
# Write a function that converts a decimal number to binary numbe

# %%
def decimal_to_binary(n):
    if n == 0:
        return "0"
    binary = ""
    while n > 0:
        remainder = n % 2
        binary = str(remainder) + binary
        n = n // 2
    return binary

num = 23
print(f"Decimal: {num}")
print(f"Binary: {decimal_to_binary(num)}")
# Out:
# Decimal: 23
# Binary: 10111

# %% [markdown]
# Write a function prodDigits() that inputs a number and returns the product of digits of that
# number

# %%
def prodDigits(n):
    product = 1
    while n > 0:
        digit = n % 10
        product *= digit
        n = n // 10
    return product

num = 234
print(f"Product of digits of {num} is {prodDigits(num)}")
# Out:
# Product of digits of 234 is 24
